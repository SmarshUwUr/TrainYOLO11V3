# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path = "/content/drive/MyDrive/EntrenamientoYOLO11V2/WheelchairsYolo11V2.zip"

# %%
# !unzip -q "{zip_path}" -d "/content/"

# %% [markdown]
# # Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/112.6 GB disk)

# %%
# !yolo detect train data=/content/data.yaml model=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial/weights/best.pt epochs=75 imgsz=320 patience=25 mosaic=0 dropout=0.0 plots=True project=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados name=entrenamiento_inicial_v2
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=75, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial/weights/best.pt, momentum=0.937, mosaic=0, multi_scale=False, name=entrenamiento_inicial_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 41.9MB/s]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 10.8±1.8 MB/s, size: 16.2 KB)
# train: Scanning /content/train/labels... 5015 images, 0 backgrounds, 0 corrupt: 100% 5015/5015 [00:03<00:00, 1409.56it/s]
# train: New cache created: /content/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4.3±2.6 MB/s, size: 16.7 KB)
# val: Scanning /content/valid/labels... 403 images, 0 backgrounds, 0 corrupt: 100% 403/403 [00:00<00:00, 802.86it/s]
# val: New cache created: /content/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75     0.666G     0.8182     0.3908      1.051         13        320: 100% 314/314 [00:48<00:00,  6.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:03<00:00,  3.52it/s]
#                    all        403        453      0.958      0.971       0.99      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75     0.811G     0.9062     0.4517      1.102          7        320: 100% 314/314 [00:45<00:00,  6.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.83it/s]
#                    all        403        453      0.924      0.934      0.976      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75     0.826G     0.9718     0.4993      1.133          7        320: 100% 314/314 [00:43<00:00,  7.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.89it/s]
#                    all        403        453      0.951      0.952      0.987      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75      0.84G       1.01     0.5372      1.155          7        320: 100% 314/314 [00:43<00:00,  7.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.49it/s]
#                    all        403        453       0.94       0.93       0.98       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75     0.855G      1.013     0.5338      1.154         10        320: 100% 314/314 [00:43<00:00,  7.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.76it/s]
#                    all        403        453       0.95      0.929       0.98      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/75     0.871G      1.003     0.5322      1.155          8        320: 100% 314/314 [00:43<00:00,  7.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.72it/s]
#                    all        403        453      0.956      0.949      0.987      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/75     0.885G     0.9978       0.53      1.157          7        320: 100% 314/314 [00:43<00:00,  7.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:03<00:00,  4.32it/s]
#                    all        403        453      0.958      0.947      0.984      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/75       0.9G     0.9918     0.5161       1.15          8        320: 100% 314/314 [00:43<00:00,  7.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6
10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.88it/s]
#                    all        403        453      0.991      0.996      0.995       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/75      1.83G     0.7019     0.3236     0.9925          9        320: 100% 314/314 [00:44<00:00,  7.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.97it/s]
#                    all        403        453      0.984          1      0.995      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/75      1.85G     0.6931      0.318     0.9945         11        320: 100% 314/314 [00:44<00:00,  7.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.97it/s]
#                    all        403        453      0.987      0.998      0.995      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/75      1.86G     0.6926     0.3171     0.9897          7        320: 100% 314/314 [00:44<00:00,  7.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.81it/s]
#                    all        403        453      0.989      0.996      0.995      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/75      1.88G     0.6855     0.3155     0.9905          7        320: 100% 314/314 [00:44<00:00,  7.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.91it/s]
#                    all        403        453      0.987      0.998      0.995      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/75      1.89G     0.6908     0.3156     0.9898          7        320: 100% 314/314 [00:44<00:00,  7.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:01<00:00,  6.64it/s]
#                    all        403        453      0.987      0.998      0.995      0.828
#
# 75 epochs completed in 0.973 hours.
# Optimizer stripped from /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/last.pt, 5.4MB
# Optimizer stripped from /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best.pt, 5.4MB
#
# Validating /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best.pt...
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:04<00:00,  3.16it/s]
#                    all        403        453      0.987          1      0.995       0.83
# Speed: 0.2ms preprocess, 1.6ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLO model to any supported format below with the `format` argument, i.e. `format=onnx`. See [Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format | `format` Argument | Model | Metadata | Arguments |
# |--------|-----------------|-------|----------|------------|
# | [PyTorch](https://pytorch.org/) | - | `yolo11n.pt` | ✅ | - |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript) | `torchscript` | `yolo11n.torchscript` | ✅ | `imgsz`, `batch`, `optimize`, `half`, `nms`, `device` |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx) | `onnx` | `yolo11n.onnx` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `opset`, `simplify`, `nms`, `device` |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino) | `openvino` | `yolo11n_openvino_model/` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt) | `engine` | `yolo11n.engine` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `simplify`, `nms`, `fraction`, `device`, `data`, `workspace` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml) | `coreml` | `yolo11n.mlpackage` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model` | `yolo11n_saved_model/` | ✅ | `imgsz`, `batch`, `int8`, `keras`, `nms`, `device` |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef) | `pb` | `yolo11n.pb` | ❌ | `imgsz`, `batch`, `device` |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite) | `tflite` | `yolo11n.tflite` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu) | `edgetpu` | `yolo11n_edgetpu.tflite` | ✅ | `imgsz`, `device` |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs) | `tfjs` | `yolo11n_web_model/` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle) | `paddle` | `yolo11n_paddle_model/` | ✅ | `imgsz`, `batch`, `device` |
# | [MNN](https://docs.ultralytics.com/integrations/mnn) | `mnn` | `yolo11n.mnn` | ✅ | `imgsz`, `batch`, `half`, `int8`, `device` |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn) | `ncnn` | `yolo11n_ncnn_model/` | ✅ | `imgsz`, `batch`, `half`, `device` |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500) | `imx` | `yolo11n_imx_model/` | ✅ | `imgsz`, `int8`, `fraction`, `device`, `data` |
# | [RKNN](https://docs.ultralytics.com/integrations/rockchip-rknn) | `rknn` | `yolo11n_rknn_model/` | ✅ | `imgsz`, `batch`, `name`, `device` |

# %%
# !yolo export model=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best.pt format=tflite int8=True data=/content/data.yaml imgsz=320 fraction=0.1
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 5, 2100) (5.2 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752475605.424108   25606 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752475605.430552   25606 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirement ['onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 5.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.59...
# ONNX: export success ✅ 1.8s, saved as '/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best.onnx' (10.0 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=/content/data.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 805.5±178.6 MB/s, size: 22.6 KB)
# Scanning /content/valid/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
# WARNING ⚠️ TensorFlow SavedModel: >300 images recommended for INT8 calibration, found 40 images.
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.1...
# Saved artifact at '/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 320, 320, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 5, 2100), dtype=tf.float32, name=None)
# Captures:
#   133909056694096: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133909056691600: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   133909056694864: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133909056696016: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133909056698512: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   133909056699088: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909056692752: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   133909056699472: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038596560: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038596944: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909056698128: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   133909056699664: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   133909056699856: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   133909056699280: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133909056700048: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909056700240: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038597904: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   133909038598480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038597136: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133909038598288: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133909038598672: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038598864: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133909038599248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038599824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038599632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038600592: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   133909038601936: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133909038599440: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   133909038599056: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038600016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038600208: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038602128: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   133909038602320: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909038601360: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133909038600784: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   133909038601168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909038602512: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133909038602896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909038603472: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038603280: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038604240: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133909038605584: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038605968: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133909038605776: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038602704: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133909038605008: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038606352: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133909038606544: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038604816: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133909038603088: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133909038606736: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038604432: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133909038607312: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133909038607120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038603664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038603856: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038607504: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   133909038606160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909038607888: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133909038607696: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   133909038606928: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133909038608080: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   133909038608464: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133909038609040: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038608848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038609808: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133909038611152: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038611536: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133909038611344: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038608272: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133909038610576: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038611920: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133909038612112: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038610384: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133909038608656: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133909038611728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038610000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133909038612304: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133908934738384: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909038609232: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133909038609424: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133908934738576: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   133908934738000: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133908934738768: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133908934738960: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133908934739152: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   133908934739344: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133908934739536: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   133908934739728: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133908934740304: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133908934738192: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133908934742608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133908934741456: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909056691024: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133909056691216: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909056688336: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133909056690256: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133909056690448: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133909056689872: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133909056690640: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   133909056690064: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133909101257616: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   133909101256848: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#
TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133909050162256: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133909050158608: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133909050158224: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133909050161488: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#   133909050159760: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#   133909050158032: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133909050160144: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
# I0000 00:00:1752475637.727595   25606 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752475637.727792   25606 single_machine.cc:361] Starting new session
# W0000 00:00:1752475639.104258   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475639.104300   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1752475640.445013   25606 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1752475640.445152   25606 single_machine.cc:361] Starting new session
# W0000 00:00:1752475641.725344   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475641.725382   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1752475643.065684   25606 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1752475643.065828   25606 single_machine.cc:361] Starting new session
# W0000 00:00:1752475644.772427   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475644.772467   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
#
#
# W0000 00:00:1752475648.548276   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475648.548313   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1752475648.651157   25606 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# W0000 00:00:1752475670.045120   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475670.045152   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# W0000 00:00:1752475691.733204   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475691.733235   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# W0000 00:00:1752475728.792479   25606 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752475728.792522   25606 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TensorFlow SavedModel: export success ✅ 159.6s, saved as '/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best_saved_model' (36.7 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best_saved_model/best_int8.tflite' (2.7 MB)
#
# Export complete (159.9s)
# Results saved to /content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best_saved_model/best_int8.tflite imgsz=320 int8
# Validate:        yolo val task=detect model=/content/drive/MyDrive/EntrenamientoYOLO11V2_Resultados/entrenamiento_inicial_v2/weights/best_saved_model/best_int8.tflite imgsz=320 data=/content/data.yaml int8
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO11 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO11 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO11 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.yaml')  # build a new model from scratch
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format
